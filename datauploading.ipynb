# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('/content/books.csv')

# %%
df
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %% [markdown]
# Picking the first ten set of data in the list

# %%
df.head(10)
# Out:
#    Identifier              Edition Statement  \
# 0         206                            NaN
# 1         216                            NaN
# 2         218                            NaN
# 3         472                            NaN
# 4         480   A new edition, revised, etc.
# 5         481  Fourth edition, revised, etc.
# 6         519                            NaN
# 7         667                            NaN
# 8         874                            NaN
# 9        1143                            NaN
#
#                   Place of Publication Date of Publication  \
# 0                               London         1879 [1878]
# 1             London; Virtue & Yorston                1868
# 2                               London                1869
# 3                               London                1851
# 4                               London                1857
# 5                               London                1875
# ...

# %% [markdown]
# Dropping unwanted data.
# Make sure you always type the right spelling as given in the data.

# %%
go=['Edition Statement', 'Identifier','Place of Publication','Date of Publication','Flickr URL']

# %%
df.drop(go, inplace=True, axis=1)

# %%
df.head(5)
# Out:
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of â€œAll for ...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  Corporate Author  \
# 0      A. A.                               FORBES, Walter.               NaN
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3  A., E. S.                   Appleyard, Ernest Silvanus.               NaN
# 4  A., E. S.                           BROOME, John Henry.               NaN
#
# ...

# %% [markdown]
# Changing index of dataframes

# %%
df=df.set_index('Author')

# %%
df.head(10)
# Out:
#                            Publisher  \
# Author
# A. A.               S. Tinsley & Co.
# A., A. A.               Virtue & Co.
# A., A. A.      Bradbury, Evans & Co.
# A., E. S.              James Darling
# A., E. S.       Wertheim & Macintosh
# A., E. S.          William Macintosh
# A., F. E.                 The Author
# A., J.|A., J.                    NaN
# RemaÊ¿.                          NaN
# A., T.                           NaN
#
#                                                            Title  \
# Author
# A. A.                          Walter Forbes. [A novel.] By A. A
# A., A. A.      All for Greed. [A novel. The dedication signed...
# A., A. A.      Love the Avenger. By the author of â€œAll for ...
# A., E. S.      Welsh Sketches, chiefly ecclesiastical, to the...
# A., E. S.      [The World in which I live, and my place in it...
# A., E. S.      [The World in which I live, and my place in it...
# A., F. E.      Lagonells. By the author of Darmayne (F. E. A....
# ...

# %% [markdown]
# Locate a book.

# %%
df.iloc[20]
# Out:
# Publisher                                                        The Author
# Title                     Peace: a lyric poem. [With prefatory address b...
# Contributors                                             WRANGHAM, Francis.
# Corporate Author                                                        NaN
# Corporate Contributors                                                  NaN
# Former owner                                                            NaN
# Issuance type                                                   monographic
# Shelfmarks                                 British Library HMNTS 11641.f.1.
# Name: ABBOTT, Thomas Eastoe., dtype: object

# %%
df=pd.read_csv('/content/books.csv')

# %%
df.loc[1950:,'Date of Publication'].head()
# Out:
# 1950    1766
# 1951    1872
# 1952    1887
# 1953    1874
# 1954    1860
# Name: Date of Publication, dtype: object

# %%
extr = df['Date of Publication'].str.extract(r'^(\d{4})',expand=False)

# %%
extr.head(10)
# Out:
# 0    1879
# 1    1868
# 2    1869
# 3    1851
# 4    1857
# 5    1875
# 6    1872
# 7     NaN
# 8    1676
# 9    1679
# Name: Date of Publication, dtype: object

# %%
df['Place of Publication'].head(10)
# Out:
# 0                                 London
# 1               London; Virtue & Yorston
# 2                                 London
# 3                                 London
# 4                                 London
# 5                                 London
# 6                                 London
# 7    pp. 40. G. Bryan & Co: Oxford, 1898
# 8                                London]
# 9                                 London
# Name: Place of Publication, dtype: object

# %%
pub = df['Place of Publication']
london = pub.str.contains('London')

# %%
london
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8282     True
# 8283    False
# 8284     True
# 8285    False
# 8286     True
# Name: Place of Publication, Length: 8287, dtype: bool

# %%
oxford = pub.str.contains('Oxford')

# %%
oxford
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8282    False
# 8283    False
# 8284    False
# 8285    False
# 8286    False
# Name: Place of Publication, Length: 8287, dtype: bool

# %%
data=pd.read_csv('/content/books.csv')

# %%
data.head(5)
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of â€œAll for ...  A., A. A.
# ...

# %%
data= pd.read_csv('/content/books.csv', header = 1)

# %%
data.head(5)
# Out:
#    206                     Unnamed: 1                    London 1879 [1878]  \
# 0  216                            NaN  London; Virtue & Yorston        1868
# 1  218                            NaN                    London        1869
# 2  472                            NaN                    London        1851
# 3  480   A new edition, revised, etc.                    London        1857
# 4  481  Fourth edition, revised, etc.                    London        1875
#
#         S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A  \
# 0           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 1  Bradbury, Evans & Co.  Love the Avenger. By the author of â€œAll for ...
# 2          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 3   Wertheim & Macintosh  [The World in which I live, and my place in it...
# 4      William Macintosh  [The World in which I live, and my place in it...
#
# ...
